# %% [markdown]
# Note: This script is to suplement `gan_generate_wforms.ipynb` and run atop its kernal to visualize the tensorflow graph.

# %%
show_graph(gm.graph.as_graph_def());
# Out:
#         <iframe seamless style="width:1200px;height:620px;border:0" srcdoc="
#         <script>
#           function load() {
# ...
